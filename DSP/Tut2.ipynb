# %%
import matplotlib.pyplot as plt
% matplotlib inline
import numpy as np
from math import pi

# %%
f = 1                   # signal freq
fs = 10                 # sample freq

# %%
t = np.arange(-1 ,1+1/fs, 1/fs)
x = np.sin(2*pi*f*t)

# %%
plt.plot(t, x)
