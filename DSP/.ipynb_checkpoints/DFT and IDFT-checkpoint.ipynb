# %% [markdown]
# # DFT

# %%
import cmath
from math import pi
import numpy as np
import matplotlib.pyplot as plt

% matplotlib inline

# %% [markdown]
# ### 1. Implement DFT and IDFT using Iteration

# %%
def DFT_loop(x):
    N = len(x)
    Wn = cmath.exp(-2J*pi/N)
    return [sum([x[i]*(Wn**(i*j)) for i in range(N)]) for j in range(N)]

# %%
def IDFT_loop(x):
    N = len(x)
    Wn = cmath.exp(-2J*pi/N)
    return [sum([x[i]*(Wn**(-i*j))/N for i in range(N)]) for j in range(N)]

# %%
f = 10
t = np.linspace(0, 1/f, 11)[:-1]
x = np.sin(2*pi*t*f)

plt.plot(x)

# %%
dft_x = DFT_loop(x)
idft_x = IDFT_loop(dft_x)

# %%
mag_dft = [cmath.polar(i)[0] for i in dft_x]
phase_dft = [cmath.polar(i)[1] for i in dft_x]

# %%
mag_idft = [cmath.polar(i)[0] for i in idft_x]
phase_idft = [cmath.polar(i)[1] for i in idft_x]

# %%
plt.plot(mag_dft)

# %%
plt.plot(idft_x)
# Out:
# /home/user/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### 2. Implement DFT and IDFT Matrix Multiplication

# %%
D = []
for i in range(N):
    for j in range(N):

# %% [markdown]
# ### Plot Computation time of 1 and 2
